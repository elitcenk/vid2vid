# %% [markdown]
# # Install CUDA

# %%
# !nvidia-smi #15G or more
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %% [markdown]
# # Install vid2vid

# %%
# !git clone https://github.com/elitcenk/vid2vid
# Out:
# Cloning into 'vid2vid'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 1061 (delta 4), reused 12 (delta 4), pack-reused 1030
# Receiving objects: 100% (1061/1061), 168.39 MiB | 45.15 MiB/s, done.
# Resolving deltas: 100% (283/283), done.

# %% [markdown]
# ## Install required library

# %%
# !pip install dominate requests

# %%
#PyTorch 1.7.1 with 10.1 CUDA version
# !pip install torch==1.7.1+cu101 torchvision==0.8.2+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install "pillow<7"
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 735.4MB 24kB/s
# ...
#      |████████████████████████████████| 12.8MB 52.6MB/s
# ...
#   Found existing installation: torch 1.7.1
#     Uninstalling torch-1.7.1:
#       Successfully uninstalled torch-1.7.1
#   Found existing installation: torchvision 0.8.2
#     Uninstalling torchvision-0.8.2:
#       Successfully uninstalled torchvision-0.8.2
# ...

# %%
#After running this cell, Restart runtime from Runtime above. shortcut for restarting "Ctrl + M"
#!pip install -U https://download.pytorch.org/whl/cu100/torch-1.0.0-cp36-cp36m-linux_x86_64.whl 
#!pip install torchvision==0.2.2
#!pip install "pillow<7"

# %%
#!pip install -U https://download.pytorch.org/whl/cu100/torch-1.1.0-cp36-cp36m-linux_x86_64.whl
#!pip install torchvision==0.3.0
#!pip install "pillow<7"

# %%
#!pip install -U https://download.pytorch.org/whl/cu101/torch-1.4.0-cp36-cp36m-linux_x86_64.whl
#!pip install torchvision==0.5.0
#!pip install "pillow<7"

# %% [markdown]
# ## Download datasets

# %%
import os
os.chdir('./vid2vid')

# %%
# !python scripts/download_datasets.py

# %% [markdown]
# ## Download flownet2

# %%
# !python scripts/download_flownet2.py
# Out:
# Compiling correlation kernels by nvcc...
# rm: cannot remove '../_ext': No such file or directory
# Traceback (most recent call last):
#   File "build.py", line 3, in <module>
#     import torch.utils.ffi
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/ffi/__init__.py", line 1, in <module>
#     raise ImportError("torch.utils.ffi is deprecated. Please use cpp extensions instead.")
# ImportError: torch.utils.ffi is deprecated. Please use cpp extensions instead.
# Compiling resample2d kernels by nvcc...
# rm: cannot remove 'Resample2d_kernel.o': No such file or directory
# rm: cannot remove '../_ext': No such file or directory
# Resample2d_kernel.cu:1:10: fatal error: THC.h: No such file or directory
#  #include <THC.h>
#           ^~~~~~~
# compilation terminated.
# Traceback (most recent call last):
#   File "build.py", line 3, in <module>
#     import torch.utils.ffi
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/ffi/__init__.py", line 1, in <module>
# ...

# %% [markdown]
# # Test Cityscapes Dataset

# %%
# !python scripts/download_models_flownet2.py

# %%
# !python scripts/street/download_models.py
# !python scripts/street/download_models_g1.py
# Out:
# ./checkpoints/models_g1.zip
# File downloaded
# unzipped to ./checkpoints/

# %%
# !python test.py --name label2city_1024_g1 --label_nc 35 --loadSize 1024 --n_scales_spatial 3 --use_instance --fg --n_downsample_G 2 --use_single_G
# Out:
# ------------ Options -------------
# add_face_disc: False
# aspect_ratio: 1.0
# basic_point_only: False
# batchSize: 1
# checkpoints_dir: ./checkpoints
# dataroot: datasets/Cityscapes/
# dataset_mode: temporal
# debug: False
# densepose_only: False
# display_id: 0
# display_winsize: 512
# feat_num: 3
# fg: True
# fg_labels: [26]
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 300
# input_nc: 3
# isTrain: False
# label_feat: False
# label_nc: 35
# loadSize: 1024
# load_features: False
# load_pretrain:
# local_rank: 0
# max_dataset_size: inf
# model: vid2vid
# nThreads: 2
# n_blocks: 9
# n_blocks_local: 3
# n_downsample_E: 3
# n_downsample_G: 2
# n_frames_G: 3
# n_gpus_gen: 1
# n_local_enhancers: 1
# n_scales_spatial: 3
# name: label2city_1024_g1
# ndf: 64
# nef: 32
# netE: simple
# netG: composite
# ngf: 128
# no_canny_edge: False
# no_dist_map: False
# no_first_img: False
# no_flip: False
# no_flow: False
# norm: batch
# ntest: inf
# openpose_only: False
# output_nc: 3
# ...

# %%
# !ls results/label2city_1024_g1/test_latest/stuttgart_00
# Out:
# fake_B_stuttgart_00_000000_000003_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000004_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000005_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000006_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000007_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000008_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000009_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000010_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000011_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000012_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000013_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000014_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000015_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000016_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000017_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000018_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000019_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000020_leftImg8bit.jpg
# fake_B_stuttgart_00_000000_000021_leftImg8bit.jpg
# ...

# %% [markdown]
# ## Show Images

# %%
from IPython.display import Image
Image(filename='results/label2city_1024_g1/test_latest/stuttgart_00/fake_B_stuttgart_00_000000_000003_leftImg8bit.jpg')

# %%
Image(filename='results/label2city_1024_g1/test_latest/stuttgart_00/real_A_stuttgart_00_000000_000003_leftImg8bit.png')

# %%
Image(filename='datasets/Cityscapes/test_A/stuttgart_00/stuttgart_00_000000_000003_leftImg8bit.png')

# %% [markdown]
# # Test Faces Dataset

# %%
# !python scripts/face/download_models.py

# %%
# !python test.py --name edge2face_512 --dataroot datasets/face/ --dataset_mode face --input_nc 15 --loadSize 512 --use_single_G
# Out:
# ------------ Options -------------
# add_face_disc: False
# aspect_ratio: 1.0
# basic_point_only: False
# batchSize: 1
# checkpoints_dir: ./checkpoints
# dataroot: datasets/face/
# dataset_mode: face
# debug: False
# densepose_only: False
# display_id: 0
# display_winsize: 512
# feat_num: 3
# fg: False
# fg_labels: [26]
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 300
# input_nc: 15
# isTrain: False
# label_feat: False
# label_nc: 0
# loadSize: 512
# load_features: False
# load_pretrain:
# local_rank: 0
# max_dataset_size: inf
# model: vid2vid
# nThreads: 2
# n_blocks: 9
# n_blocks_local: 3
# n_downsample_E: 3
# n_downsample_G: 3
# n_frames_G: 3
# n_gpus_gen: 1
# n_local_enhancers: 1
# n_scales_spatial: 1
# name: edge2face_512
# ndf: 64
# nef: 32
# netE: simple
# netG: composite
# ngf: 128
# no_canny_edge: False
# no_dist_map: False
# no_first_img: False
# no_flip: False
# no_flow: False
# norm: batch
# ntest: inf
# openpose_only: False
# output_nc: 3
# phase: test
# ...

# %%
# !ls
# Out:
# sample_data
